# %%
'''Considere Que a Empresa Decida Conceder o Desconto de 15% do Item Anterior. 
Qual Seria a Média do Valor de Venda Antes e Depois do Desconto?'''

# %%
#Importando bibliotecas
import pandas as pd
import numpy as np

# %%
#Abrindo arquivo CSV
data_set = pd.read_csv("dataset.csv")
data_set.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais  \
# 0  CA-2017-152156  08/11/2017   CG-12520   Consumer  United States
# 1  CA-2017-152156  08/11/2017   CG-12520   Consumer  United States
# 2  CA-2017-138688  12/06/2017   DV-13045  Corporate  United States
# 3  US-2016-108966  11/10/2016   SO-20335   Consumer  United States
# 4  US-2016-108966  11/10/2016   SO-20335   Consumer  United States
#
#             Cidade      Estado       ID_Produto        Categoria SubCategoria  \
# 0        Henderson    Kentucky  FUR-BO-10001798        Furniture    Bookcases
# 1        Henderson    Kentucky  FUR-CH-10000454        Furniture       Chairs
# 2      Los Angeles  California  OFF-LA-10000240  Office Supplies       Labels
# 3  Fort Lauderdale     Florida  FUR-TA-10000577        Furniture       Tables
# 4  Fort Lauderdale     Florida  OFF-ST-10000760  Office Supplies      Storage
#
#    Valor_Venda
# 0     261.9600
# 1     731.9400
# 2      14.6200
# 3     957.5775
# ...

# %%
#Criando nova coluna com desconto 15%
data_set["Desconto"] = np.where(data_set["Valor_Venda"] > 1000, 0.15, 0.10)
data_set.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais  \
# 0  CA-2017-152156  08/11/2017   CG-12520   Consumer  United States
# 1  CA-2017-152156  08/11/2017   CG-12520   Consumer  United States
# 2  CA-2017-138688  12/06/2017   DV-13045  Corporate  United States
# 3  US-2016-108966  11/10/2016   SO-20335   Consumer  United States
# 4  US-2016-108966  11/10/2016   SO-20335   Consumer  United States
#
#             Cidade      Estado       ID_Produto        Categoria SubCategoria  \
# 0        Henderson    Kentucky  FUR-BO-10001798        Furniture    Bookcases
# 1        Henderson    Kentucky  FUR-CH-10000454        Furniture       Chairs
# 2      Los Angeles  California  OFF-LA-10000240  Office Supplies       Labels
# 3  Fort Lauderdale     Florida  FUR-TA-10000577        Furniture       Tables
# 4  Fort Lauderdale     Florida  OFF-ST-10000760  Office Supplies      Storage
#
#    Valor_Venda  Desconto
# 0     261.9600       0.1
# 1     731.9400       0.1
# ...

# %%
#Criando coluna com o desconto aplicado.
data_set["Valor_Com_Desconto"] = data_set["Valor_Venda"] - data_set["Valor_Venda"] * data_set["Desconto"]
data_set.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais  \
# 0  CA-2017-152156  08/11/2017   CG-12520   Consumer  United States
# 1  CA-2017-152156  08/11/2017   CG-12520   Consumer  United States
# 2  CA-2017-138688  12/06/2017   DV-13045  Corporate  United States
# 3  US-2016-108966  11/10/2016   SO-20335   Consumer  United States
# 4  US-2016-108966  11/10/2016   SO-20335   Consumer  United States
#
#             Cidade      Estado       ID_Produto        Categoria SubCategoria  \
# 0        Henderson    Kentucky  FUR-BO-10001798        Furniture    Bookcases
# 1        Henderson    Kentucky  FUR-CH-10000454        Furniture       Chairs
# 2      Los Angeles  California  OFF-LA-10000240  Office Supplies       Labels
# 3  Fort Lauderdale     Florida  FUR-TA-10000577        Furniture       Tables
# 4  Fort Lauderdale     Florida  OFF-ST-10000760  Office Supplies      Storage
#
#    Valor_Venda  Desconto  Valor_Com_Desconto
# 0     261.9600       0.1           235.76400
# ...

# %%
#Filtrando colunas com desconto igual a 15%
Valor_Venda = data_set.loc[data_set["Desconto"] == 0.15, "Valor_Venda"]
Valor_Com_Desconto = data_set.loc[data_set["Desconto"] == 0.15, "Valor_Com_Desconto"]

#Tirando a media dos valores
Media_Valor_Venda = Valor_Venda.mean()
Media_Valor_Com_Desconto = Valor_Com_Desconto.mean()

# %%
#exibindo resultados
print(f'media das vendas sem desconto:{Media_Valor_Venda}, media das vendas com desconto:{Media_Valor_Com_Desconto}')
# Out:
# media das vendas sem desconto:2116.8078153172864, media das vendas com desconto:1799.2866430196952
